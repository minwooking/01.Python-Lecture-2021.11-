# %% [markdown]
# # Unit17.While 반복문

# %% [markdown]
# ㅇ 횟수가 정해지지 않은 반복문

# %%
import random as rd  # random 의 별칭 rd
rd.seed(2021)
dice = rd.randint(1,6)
while dice != 3 :
    print(dice, end=' ')
    dice = rd.randint(1,6)
# Out:
# 4 6 5
