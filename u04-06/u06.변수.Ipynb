# %% [markdown]
# ### Unit 6. 변수(Variable)

# %%
### 6-1. 변수 만들기
# = 할당하다
#R프로그램에서는 = == <-5
X = 10 
X
# Out:
# 10

# %%
lbs_weight = 174.5  # 변수 snake 표기법
InchHeight = 50 # 변수 camel 표기법

# %%
# tuple unPacking 다중 변수 선언 파이썬에서만 가능함 

x,y,z = 10,20,30

# %%
# 데이터가 () 로 묶여 있으면 튜플
# 데이터가 [] 로 묶여 있으면 리스트
# 데이터가 {} 로 묶여 있으면 딕셔너리

# %%
x, y = y, x  # 파이썬에서 의 이항연산 하지만 그냥 다른거 하는게 더 좋아보임
x,y
# Out:
# (10, 10)

# %%
# 파이썬에서는 빈 변수를 만들어주기위해선 None을 쓴다 
#""" y= None
#print(q)
#print(y) """
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-a3788678898a> in <module>
# ----> 1 q= null;
#       2 y= None
#       3 print(q)
#       4 print(y)
#
# NameError: name 'null' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-a6ad026a9962> in <module>
# ----> 1 x = x + y
#
# TypeError: unsupported operand type(s) for +: 'int' and 'NoneType'

# %%
x = x + y
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-a6ad026a9962> in <module>
# ----> 1 x = x + y
#
# TypeError: unsupported operand type(s) for +: 'int' and 'NoneType'

# %%
sum = 0;

for i in range(1,101):
    sum = sum+i

print(sum)
# Out:
# 5050

# %%
# (x += Y) == (X = X+Y)

# %%
input('숫자를 입력하세요.')
# Out:
# '50'

# %%
input(int())
# Out:
# '50'

# %%
number = int(input('정수를 입력하세요'))

# %%
print(number)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-03090db32dff> in <module>
# ----> 1 print(number)
#
# TypeError: 'int' object is not callable

# %%
print(number)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-03090db32dff> in <module>
# ----> 1 print(number)
#
# TypeError: 'int' object is not callable

# %%
print(number)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-03090db32dff> in <module>
# ----> 1 print(number)
#
# TypeError: 'int' object is not callable

# %%
print(number)

# %%
number = int(input('정수를입력하세요'))

# %%
print(number)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-03090db32dff> in <module>
# ----> 1 print(number)
#
# TypeError: 'int' object is not callable

# %%
num1, num2 = int(input('정수입력'),input('2번째 정수입력'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-f4925f47f07f> in <module>
# ----> 1 num1, num2 = int(input('정수입력'),input('2번째 정수입력'))
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
s = input('정수 두개 입력')

# %%
# split 나눌때 사용함


s.split() # 30 40 나눌때 씀 중요함
# Out:
# ['30', '40']

# %%
 list(map(int, s.split()))
# Out:
# [30, 40]

# %%
map(int, s.split())

# %%
num1, num2 = map(int, s.split())
num1, num2
# Out:
# (30, 40)

# %% [markdown]
# # 정수 두개 입력 받는 방법

# %%
# 정수 두개 입력 받는 방법 
num1 , num2 = map(int, input('정수 두개 입력').split())
num1 , num2
# Out:
# (300, 400)

# %%
10 + 20, # 정수형 30
'10' + '20' # 문자열 1020
# Out:
# (30, '1020')

# %%
s = input()

# %%
s
# Out:
# '10 20'

# %%
a,b, = s.split()

# %%
a,b
# Out:
# ('10', '20')

# %%
int(a,b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-8be66dccab10> in <module>
# ----> 1 int(a,b)
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
int (a)
# Out:
# 10

# %%
int(b)
# Out:
# 20

# %%
a+b
# Out:
# '1020'

# %%
int(a) + int(b)
# Out:
# 30

# %%
list(map(int,s.split))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-4bd8201d6bff> in <module>
# ----> 1 list(map(int,s.split))
#
# TypeError: 'builtin_function_or_method' object is not iterable

# %%
# 외워야 함 num1 , num2 = map(int, input('정수 두개 입력').split())

# %%
num1, num2 = map(int, input('정수두개를입력')())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-91a82c334ce3> in <module>
# ----> 1 num1, num2 = map(int, input('정수두개를입력')())
#
# TypeError: 'str' object is not callable

# %%
num1, num2 = map(int, input('정수두개를입력')())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-91a82c334ce3> in <module>
# ----> 1 num1, num2 = map(int, input('정수두개를입력')())
#
# TypeError: 'str' object is not callable

# %%
num3, num4 = map(int, input('정수두개를입력')())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-5fd473495bc0> in <module>
# ----> 1 num3, num4 = map(int, input('정수두개를입력')())
#
# TypeError: 'str' object is not callable

# %%
num1, num2 = map(int, input('정수두개를입력').split())

# %%
num1,num2
# Out:
# (30, 40)

# %%
# map 이라는 함수가 굉장히 좋은 함수  
# 있고 없고의 차이점
# 있으면 num1, num2 = map(int, input('정수두개를입력').split())
# split은 스플릿에 어떤 값을 줬냐에 따라서 나누어줌

# %%
num1, num2, num3 = map(int, input('정수두개를입력').split())

# %%
num1,num2, num3
# Out:
# (10, 20, 30)

# %%
n1, n2 = map(int,input('정수 두개를 입력할꺼고 나누어줌').split)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-02f021ebd75c> in <module>
# ----> 1 n1, n2 = map(int,input('정수 두개를 입력할꺼고 나누어줌').split)
#
# TypeError: 'builtin_function_or_method' object is not iterable
